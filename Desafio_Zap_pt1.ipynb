# %%
ref_arquivo = open("C:\\Users\\Zangelmi\\Desktop\\Python\\chat_.txt",'r',encoding='utf-8')

for linha in ref_arquivo:
    valores = linha.split()
    print(linha)
# Out:
# [23/04/20 20:25:59] MBA Impacta Big Data T21: ‎Messages to this group are now secured with end-to-end encryption.
#
# [23/04/20 20:25:59] ‎‪+55 11 99286‑6200‬ created this group
#
# [23/04/20 20:33:11] ‎You joined using this group's invite link
#
# [23/04/20 20:33:21] ‎You're now an admin
#
# [23/04/20 20:33:27] ‎‪+55 11 95656‑2261‬ joined using this group's invite link
#
# [23/04/20 20:33:36] ‎‪+55 11 96037‑1748‬ joined using this group's invite link
#
# [23/04/20 20:33:49] ‪+55 11 95656‑2261‬: Olá ✌🏻
#
# [23/04/20 20:34:38] ‪+55 11 99286‑6200‬: Alguém escolhe uma foto?
#
# [23/04/20 20:35:15] ‎‪+55 11 98934‑9779‬ joined using this group's invite link
#
# [23/04/20 20:36:21] ‎‪+55 11 98667‑5675‬ changed this group's icon
#
# [23/04/20 20:36:05] ‎‪+55 11 94904‑8485‬ joined using this group's invite link
#
# [23/04/20 20:38:25] ‎‪+55 11 99143‑0838‬ joined using this group's invite link
#
# [23/04/20 20:38:30] ‎‪+55 11 99306‑9003‬ joined using this group's invite link
#
# ...

# %%
ref_arquivo = open("C:\\Users\\Zangelmi\\Desktop\\Python\\chat_.txt",'r',encoding='utf-8')

linha = ref_arquivo.readline()

list_datas = []
list_erros_formatacao = []
lista_pessoas = []
list_msg = []

while linha:
    linha = ref_arquivo.readline()
    
    try :
        date_time_obj =datetime.datetime.strptime(linha[1:20],'%d/%n/%Y %H:%M:%S')
        list_datas.appened(data_time_obj)
        msg = linha[21:]
        if(len(msg.split(':'))=>2):
            list_pessoas.appened(msg.split(':')[0])
            list_msg.appened(msg.split(':')[1])
    except ValueERRO:
        list_erros_formatacao.appened('Erros de formatacao data')
ref_arquivo.close()
# Out:
#   File "<ipython-input-10-cbbbb6887c4c>", line 17
#     if(len(msg.split(':'))=>2):
#                           ^
# SyntaxError: invalid syntax

# %%
strings = open("C:\\Users\\Zangelmi\\Desktop\\Python\\chat_.txt",'r',encoding='utf-8')
stringss = strings.readline()

for c in range(len(stringss)):
        for d in stringss[c]:
            if(stringss[c][d].isalnum != True):
                #something that removes stringss[c][d]
                total+=1
print("words: "+ str(total))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-92891c0d8320> in <module>
#       4 for c in range(len(stringss)):
#       5         for d in stringss[c]:
# ----> 6             if(stringss[c][d].isalnum != True):
#       7                 #something that removes stringss[c][d]
#       8                 total+=1
#
# TypeError: string indices must be integers
